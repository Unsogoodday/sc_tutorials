# %%
import numpy as np
import matplotlib.pyplot as pl
import scanpy as sc

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
results_file = "./write/paul15.h5ad"
### assigning a relative path string to the variable results_file
### ./ means currend working directory.

# low dpi (dots per inch) yields small inline figures
sc.settings.set_figure_params(dpi=80, frameon=False, figsize=(3, 3), facecolor="white")
# Out:
# -----
# anndata     0.8.0
# scanpy      1.9.3
# -----
# PIL                 8.0.1
# backcall            0.2.0
# cached_property     1.5.2
# cffi                1.14.3
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.1
# decorator           4.4.2
# google              NA
# h5py                3.0.0
# igraph              0.10.8
# ipykernel           5.3.4
# ipython_genutils    0.2.0
# jedi                0.17.2
# joblib              0.17.0
# kiwisolver          1.3.1
# leidenalg           0.10.2
# llvmlite            0.34.0
# matplotlib          3.5.3
# mpl_toolkits        NA
# natsort             8.4.0
# numba               0.51.2
# numpy               1.19.4
# packaging           20.4
# pandas              1.1.4
# parso               0.7.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prompt_toolkit      3.0.8
# ptyprocess          0.6.0
# pygments            2.7.2
# pyparsing           2.4.7
# ...

# %%
adata = sc.datasets.paul15()
adata

### 'paul15' is a default built-in dataset for tutoria;
### all scanpy datasets have to be gene X cell matrix (row is gene)
# Out:
# WARNING: In Scanpy 0.*, this returned logarithmized data. Now it returns non-logarithmized data.
# ...
# /usr/local/lib/python3.7/site-packages/anndata/compat/_overloaded_dict.py:106: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   self.data[key] = value
# AnnData object with n_obs × n_vars = 2730 × 3451
#     obs: 'paul15_clusters'
#     uns: 'iroot'

# %%
sc.pp.recipe_zheng17(adata)

### 노션 참조
# Out:
# running recipe zheng17
# normalizing counts per cell
#     finished (0:00:00)
# extracting highly variable genes
#     finished (0:00:00)
# normalizing counts per cell
#     finished (0:00:00)
#     finished (0:00:00)
